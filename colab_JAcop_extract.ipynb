# %% [markdown]
# <a href="https://colab.research.google.com/github/AlanWu886/JAcop_postProcess/blob/main/colab_JAcop_extract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlanWu886/JAcop_postProcess.git
# Out:
# Cloning into 'JAcop_postProcess'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 24 (delta 6), reused 16 (delta 2), pack-reused 0
# Unpacking objects: 100% (24/24), done.

# %%
import pandas as pd
import re
import glob
import os


def collect_all_txt_file_name(path="./"):
    print(os.listdir())
    print(os.getcwd())
    os.chdir(path)
    txt_files = glob.glob('*.txt')
    print(txt_files)
    return txt_files


def brake_down_txt(name):
    txt = open(name, "r").read().splitlines()
    # print(txt)
    data = []
    data_point = []
    for line in txt:
        print(line)
        if re.match("(^\\*+$)", line):
            if len(data_point) != 0:
                data.append(data_point)
            data_point = []
            print("adding data point...")
        else:
            data_point.append(line)

    data.append(data_point)
    # print(len(data), data)
    return data


def construct_data_frame(data):
    single_file_df = pd.DataFrame()
    for row in data:
        data_txt = '\n'.join(row)
        # print(data_txt)
        name = re.findall(r'Image\s\w+:.+', data_txt)
        name_txt = '& '.join(name)
        numbers = re.findall(r'\w+=[^1][\w\\.]+\S', data_txt)
        attributes = {'name': ' & '.join(name)}
        print(name_txt, numbers)

        for item in numbers:
            pair = item.split("=")
            print(pair)
            attributes[pair[0]] = pair[1]
        print(attributes)
        single_file_df = single_file_df.append(attributes, ignore_index=True)
    return single_file_df

def main():
    df = pd.DataFrame()

    txt_collection = collect_all_txt_file_name()
    file_count = 0
    for txt in txt_collection:
        file_count += 1
        data = brake_down_txt(txt)
        df = pd.concat([df, construct_data_frame(data)])
    print("pre process done, total " + str(file_count) + " file(s)...")
    print(df)
    df.to_excel(r'test.xlsx', index=False, header=True)


if __name__ == "__main__":
    main()
# Out:
# ['Log.txt', 'README.md', 'RH.txt', 'extract.py', '.idea', 'WT.txt', '.\\test.xlsx', '.ipynb_checkpoints', '.git']
# /content/JAcop_postProcess
# ['Log.txt', 'RH.txt', 'WT.txt']
# **************************************************
# adding data point...
# Image A: M1 Spast WT LD.tiff
# Image B: M1 Spast WT Prs.tiff
#
# Pearson's Coefficient:
# r=0.412
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.213 (fraction of A overlapping B)
# M2=0.891 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: M1 Spast WT LD-2.tiff
# Image B: M1 Spast WT Prs-2.tiff
#
# Pearson's Coefficient:
# r=0.519
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.295 (fraction of A overlapping B)
# M2=0.985 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: M1 Spast WT LD-3.tiff
# Image B: M1 Spast WT Prs-3.tiff
#
# Pearson's Coefficient:
# r=0.425
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.199 (fraction of A overlapping B)
# M2=0.99 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: M1 Spast WT LD-4.tiff
# Image B: M1 Spast WT Prs-4.tiff
#
# Pearson's Coefficient:
# r=0.593
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.482 (fraction of A overlapping B)
# M2=0.863 (fraction of B overlapping A)
# Image A: M1 Spast WT LD.tiff& Image B: M1 Spast WT Prs.tiff ['r=0.412', 'M1=0.213', 'M2=0.891']
# ['r', '0.412']
# ['M1', '0.213']
# ['M2', '0.891']
# {'name': 'Image A: M1 Spast WT LD.tiff & Image B: M1 Spast WT Prs.tiff', 'r': '0.412', 'M1': '0.213', 'M2': '0.891'}
# Image A: M1 Spast WT LD-2.tiff& Image B: M1 Spast WT Prs-2.tiff ['r=0.519', 'M1=0.295', 'M2=0.985']
# ['r', '0.519']
# ['M1', '0.295']
# ['M2', '0.985']
# {'name': 'Image A: M1 Spast WT LD-2.tiff & Image B: M1 Spast WT Prs-2.tiff', 'r': '0.519', 'M1': '0.295', 'M2': '0.985'}
# Image A: M1 Spast WT LD-3.tiff& Image B: M1 Spast WT Prs-3.tiff ['r=0.425', 'M1=0.199', 'M2=0.99']
# ['r', '0.425']
# ['M1', '0.199']
# ['M2', '0.99']
# {'name': 'Image A: M1 Spast WT LD-3.tiff & Image B: M1 Spast WT Prs-3.tiff', 'r': '0.425', 'M1': '0.199', 'M2': '0.99'}
# Image A: M1 Spast WT LD-4.tiff& Image B: M1 Spast WT Prs-4.tiff ['r=0.593', 'M1=0.482', 'M2=0.863']
# ['r', '0.593']
# ['M1', '0.482']
# ['M2', '0.863']
# {'name': 'Image A: M1 Spast WT LD-4.tiff & Image B: M1 Spast WT Prs-4.tiff', 'r': '0.593', 'M1': '0.482', 'M2': '0.863'}
# **************************************************
# adding data point...
# Image A: C1-RH-1 LD.tiff
# Image B: C3-RH-1 Prs.tiff
#
# Pearson's Coefficient:
# r=0.321
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.408 (fraction of A overlapping B)
# M2=0.333 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-2 LD.tiff
# Image B: C3-RH-2 Prs.tiff
#
# Pearson's Coefficient:
# r=0.148
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.147 (fraction of A overlapping B)
# M2=0.159 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-3 LD.tiff
# Image B: C3-RH-3 Prs.tiff
#
# Pearson's Coefficient:
# r=0.072
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.093 (fraction of A overlapping B)
# M2=0.088 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-4 LD.tiff
# Image B: C3-RH-4 Prs.tiff
#
# Pearson's Coefficient:
# r=0.43
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.574 (fraction of A overlapping B)
# M2=0.349 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-5 LD.tiff
# Image B: C3-RH-5 Prs.tiff
#
# Pearson's Coefficient:
# r=0.059
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.106 (fraction of A overlapping B)
# M2=0.069 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-6 LD.tiff
# Image B: C3-RH-6 Prs.tiff
#
# Pearson's Coefficient:
# r=0.226
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.219 (fraction of A overlapping B)
# M2=0.257 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-7 LD.tiff
# Image B: C3-RH-7 Prs.tiff
#
# Pearson's Coefficient:
# r=0.118
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.098 (fraction of A overlapping B)
# M2=0.186 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-8 LD.tiff
# Image B: C3-RH-8 Prs.tiff
#
# Pearson's Coefficient:
# r=0.321
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.429 (fraction of A overlapping B)
# M2=0.271 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-9 LD.tiff
# Image B: C3-RH-9 Prs.tiff
#
# Pearson's Coefficient:
# r=0.473
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.534 (fraction of A overlapping B)
# M2=0.487 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-10 LD.tiff
# Image B: C3-RH-10 Prs.tiff
#
# Pearson's Coefficient:
# r=0.294
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.232 (fraction of A overlapping B)
# M2=0.459 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-11 LD.tiff
# Image B: C3-RH-11 Prs.tiff
#
# Pearson's Coefficient:
# r=0.386
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.488 (fraction of A overlapping B)
# M2=0.328 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-RH-12 LD.tiff
# Image B: C3-RH-12 Prs.tiff
#
# Pearson's Coefficient:
# r=0.158
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.176 (fraction of A overlapping B)
# M2=0.195 (fraction of B overlapping A)
# Image A: C1-RH-1 LD.tiff& Image B: C3-RH-1 Prs.tiff ['r=0.321', 'M1=0.408', 'M2=0.333']
# ['r', '0.321']
# ['M1', '0.408']
# ['M2', '0.333']
# {'name': 'Image A: C1-RH-1 LD.tiff & Image B: C3-RH-1 Prs.tiff', 'r': '0.321', 'M1': '0.408', 'M2': '0.333'}
# Image A: C1-RH-2 LD.tiff& Image B: C3-RH-2 Prs.tiff ['r=0.148', 'M1=0.147', 'M2=0.159']
# ['r', '0.148']
# ['M1', '0.147']
# ['M2', '0.159']
# {'name': 'Image A: C1-RH-2 LD.tiff & Image B: C3-RH-2 Prs.tiff', 'r': '0.148', 'M1': '0.147', 'M2': '0.159'}
# Image A: C1-RH-3 LD.tiff& Image B: C3-RH-3 Prs.tiff ['r=0.072', 'M1=0.093', 'M2=0.088']
# ['r', '0.072']
# ['M1', '0.093']
# ['M2', '0.088']
# {'name': 'Image A: C1-RH-3 LD.tiff & Image B: C3-RH-3 Prs.tiff', 'r': '0.072', 'M1': '0.093', 'M2': '0.088'}
# Image A: C1-RH-4 LD.tiff& Image B: C3-RH-4 Prs.tiff ['r=0.43', 'M1=0.574', 'M2=0.349']
# ['r', '0.43']
# ['M1', '0.574']
# ['M2', '0.349']
# {'name': 'Image A: C1-RH-4 LD.tiff & Image B: C3-RH-4 Prs.tiff', 'r': '0.43', 'M1': '0.574', 'M2': '0.349'}
# Image A: C1-RH-5 LD.tiff& Image B: C3-RH-5 Prs.tiff ['r=0.059', 'M1=0.106', 'M2=0.069']
# ['r', '0.059']
# ['M1', '0.106']
# ['M2', '0.069']
# {'name': 'Image A: C1-RH-5 LD.tiff & Image B: C3-RH-5 Prs.tiff', 'r': '0.059', 'M1': '0.106', 'M2': '0.069'}
# Image A: C1-RH-6 LD.tiff& Image B: C3-RH-6 Prs.tiff ['r=0.226', 'M1=0.219', 'M2=0.257']
# ['r', '0.226']
# ['M1', '0.219']
# ['M2', '0.257']
# {'name': 'Image A: C1-RH-6 LD.tiff & Image B: C3-RH-6 Prs.tiff', 'r': '0.226', 'M1': '0.219', 'M2': '0.257'}
# Image A: C1-RH-7 LD.tiff& Image B: C3-RH-7 Prs.tiff ['r=0.118', 'M1=0.098', 'M2=0.186']
# ['r', '0.118']
# ['M1', '0.098']
# ['M2', '0.186']
# {'name': 'Image A: C1-RH-7 LD.tiff & Image B: C3-RH-7 Prs.tiff', 'r': '0.118', 'M1': '0.098', 'M2': '0.186'}
# Image A: C1-RH-8 LD.tiff& Image B: C3-RH-8 Prs.tiff ['r=0.321', 'M1=0.429', 'M2=0.271']
# ['r', '0.321']
# ['M1', '0.429']
# ['M2', '0.271']
# {'name': 'Image A: C1-RH-8 LD.tiff & Image B: C3-RH-8 Prs.tiff', 'r': '0.321', 'M1': '0.429', 'M2': '0.271'}
# Image A: C1-RH-9 LD.tiff& Image B: C3-RH-9 Prs.tiff ['r=0.473', 'M1=0.534', 'M2=0.487']
# ['r', '0.473']
# ['M1', '0.534']
# ['M2', '0.487']
# {'name': 'Image A: C1-RH-9 LD.tiff & Image B: C3-RH-9 Prs.tiff', 'r': '0.473', 'M1': '0.534', 'M2': '0.487'}
# Image A: C1-RH-10 LD.tiff& Image B: C3-RH-10 Prs.tiff ['r=0.294', 'M1=0.232', 'M2=0.459']
# ['r', '0.294']
# ['M1', '0.232']
# ['M2', '0.459']
# {'name': 'Image A: C1-RH-10 LD.tiff & Image B: C3-RH-10 Prs.tiff', 'r': '0.294', 'M1': '0.232', 'M2': '0.459'}
# Image A: C1-RH-11 LD.tiff& Image B: C3-RH-11 Prs.tiff ['r=0.386', 'M1=0.488', 'M2=0.328']
# ['r', '0.386']
# ['M1', '0.488']
# ['M2', '0.328']
# {'name': 'Image A: C1-RH-11 LD.tiff & Image B: C3-RH-11 Prs.tiff', 'r': '0.386', 'M1': '0.488', 'M2': '0.328'}
# Image A: C1-RH-12 LD.tiff& Image B: C3-RH-12 Prs.tiff ['r=0.158', 'M1=0.176', 'M2=0.195']
# ['r', '0.158']
# ['M1', '0.176']
# ['M2', '0.195']
# {'name': 'Image A: C1-RH-12 LD.tiff & Image B: C3-RH-12 Prs.tiff', 'r': '0.158', 'M1': '0.176', 'M2': '0.195'}
# **************************************************
# adding data point...
# Image A: C1-WT-1 LD.tiff
# Image B: C3-WT-1 prs.tiff
#
# Pearson's Coefficient:
# r=0.264
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.227 (fraction of A overlapping B)
# M2=0.365 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-2 LD.tiff
# Image B: C3-WT-2 prs.tiff
#
# Pearson's Coefficient:
# r=0.587
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.462 (fraction of A overlapping B)
# M2=0.786 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-3 LD.tiff
# Image B: C3-WT-3 prs.tiff
#
# Pearson's Coefficient:
# r=0.338
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.213 (fraction of A overlapping B)
# M2=0.578 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-4 LD.tiff
# Image B: C3-WT-4 prs.tiff
#
# Pearson's Coefficient:
# r=0.302
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.27 (fraction of A overlapping B)
# M2=0.372 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-5 LD.tiff
# Image B: C3-WT-5 prs.tiff
#
# Pearson's Coefficient:
# r=0.6
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.677 (fraction of A overlapping B)
# M2=0.584 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-6 LD.tiff
# Image B: C3-WT-6 prs.tiff
#
# Pearson's Coefficient:
# r=0.734
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.653 (fraction of A overlapping B)
# M2=0.836 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-7 LD.tiff
# Image B: C3-WT-7 prs.tiff
#
# Pearson's Coefficient:
# r=0.303
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.2 (fraction of A overlapping B)
# M2=0.529 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-8 LD.tiff
# Image B: C3-WT-8 prs.tiff
#
# Pearson's Coefficient:
# r=0.448
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.305 (fraction of A overlapping B)
# M2=0.694 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-9 LD.tiff
# Image B: C3-WT-9 prs.tiff
#
# Pearson's Coefficient:
# r=0.384
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.318 (fraction of A overlapping B)
# M2=0.496 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-10 LD.tiff
# Image B: C3-WT-10 prs.tiff
#
# Pearson's Coefficient:
# r=0.38
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.512 (fraction of A overlapping B)
# M2=0.33 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-11 LD.tiff
# Image B: C3-WT-11 prs.tiff
#
# Pearson's Coefficient:
# r=0.498
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.388 (fraction of A overlapping B)
# M2=0.673 (fraction of B overlapping A)
# **************************************************
# adding data point...
# Image A: C1-WT-12 LD.tiff
# Image B: C3-WT-12 prs.tiff
#
# Pearson's Coefficient:
# r=0.366
#
# Manders' Coefficients (original):
# M1=1.0 (fraction of A overlapping B)
# M2=1.0 (fraction of B overlapping A)
#
# Manders' Coefficients (using threshold value of 150 for imgA and 150 for imgB):
# M1=0.332 (fraction of A overlapping B)
# M2=0.461 (fraction of B overlapping A)
# Image A: C1-WT-1 LD.tiff& Image B: C3-WT-1 prs.tiff ['r=0.264', 'M1=0.227', 'M2=0.365']
# ['r', '0.264']
# ['M1', '0.227']
# ['M2', '0.365']
# {'name': 'Image A: C1-WT-1 LD.tiff & Image B: C3-WT-1 prs.tiff', 'r': '0.264', 'M1': '0.227', 'M2': '0.365'}
# Image A: C1-WT-2 LD.tiff& Image B: C3-WT-2 prs.tiff ['r=0.587', 'M1=0.462', 'M2=0.786']
# ['r', '0.587']
# ['M1', '0.462']
# ['M2', '0.786']
# {'name': 'Image A: C1-WT-2 LD.tiff & Image B: C3-WT-2 prs.tiff', 'r': '0.587', 'M1': '0.462', 'M2': '0.786'}
# Image A: C1-WT-3 LD.tiff& Image B: C3-WT-3 prs.tiff ['r=0.338', 'M1=0.213', 'M2=0.578']
# ['r', '0.338']
# ['M1', '0.213']
# ['M2', '0.578']
# {'name': 'Image A: C1-WT-3 LD.tiff & Image B: C3-WT-3 prs.tiff', 'r': '0.338', 'M1': '0.213', 'M2': '0.578'}
# Image A: C1-WT-4 LD.tiff& Image B: C3-WT-4 prs.tiff ['r=0.302', 'M1=0.27', 'M2=0.372']
# ['r', '0.302']
# ['M1', '0.27']
# ['M2', '0.372']
# {'name': 'Image A: C1-WT-4 LD.tiff & Image B: C3-WT-4 prs.tiff', 'r': '0.302', 'M1': '0.27', 'M2': '0.372'}
# Image A: C1-WT-5 LD.tiff& Image B: C3-WT-5 prs.tiff ['r=0.6', 'M1=0.677', 'M2=0.584']
# ['r', '0.6']
# ['M1', '0.677']
# ['M2', '0.584']
# {'name': 'Image A: C1-WT-5 LD.tiff & Image B: C3-WT-5 prs.tiff', 'r': '0.6', 'M1': '0.677', 'M2': '0.584'}
# Image A: C1-WT-6 LD.tiff& Image B: C3-WT-6 prs.tiff ['r=0.734', 'M1=0.653', 'M2=0.836']
# ['r', '0.734']
# ['M1', '0.653']
# ['M2', '0.836']
# {'name': 'Image A: C1-WT-6 LD.tiff & Image B: C3-WT-6 prs.tiff', 'r': '0.734', 'M1': '0.653', 'M2': '0.836'}
# Image A: C1-WT-7 LD.tiff& Image B: C3-WT-7 prs.tiff ['r=0.303', 'M1=0.2', 'M2=0.529']
# ['r', '0.303']
# ['M1', '0.2']
# ['M2', '0.529']
# {'name': 'Image A: C1-WT-7 LD.tiff & Image B: C3-WT-7 prs.tiff', 'r': '0.303', 'M1': '0.2', 'M2': '0.529'}
# Image A: C1-WT-8 LD.tiff& Image B: C3-WT-8 prs.tiff ['r=0.448', 'M1=0.305', 'M2=0.694']
# ['r', '0.448']
# ['M1', '0.305']
# ['M2', '0.694']
# {'name': 'Image A: C1-WT-8 LD.tiff & Image B: C3-WT-8 prs.tiff', 'r': '0.448', 'M1': '0.305', 'M2': '0.694'}
# Image A: C1-WT-9 LD.tiff& Image B: C3-WT-9 prs.tiff ['r=0.384', 'M1=0.318', 'M2=0.496']
# ['r', '0.384']
# ['M1', '0.318']
# ['M2', '0.496']
# {'name': 'Image A: C1-WT-9 LD.tiff & Image B: C3-WT-9 prs.tiff', 'r': '0.384', 'M1': '0.318', 'M2': '0.496'}
# Image A: C1-WT-10 LD.tiff& Image B: C3-WT-10 prs.tiff ['r=0.38', 'M1=0.512', 'M2=0.33']
# ['r', '0.38']
# ['M1', '0.512']
# ['M2', '0.33']
# {'name': 'Image A: C1-WT-10 LD.tiff & Image B: C3-WT-10 prs.tiff', 'r': '0.38', 'M1': '0.512', 'M2': '0.33'}
# Image A: C1-WT-11 LD.tiff& Image B: C3-WT-11 prs.tiff ['r=0.498', 'M1=0.388', 'M2=0.673']
# ['r', '0.498']
# ['M1', '0.388']
# ['M2', '0.673']
# {'name': 'Image A: C1-WT-11 LD.tiff & Image B: C3-WT-11 prs.tiff', 'r': '0.498', 'M1': '0.388', 'M2': '0.673'}
# Image A: C1-WT-12 LD.tiff& Image B: C3-WT-12 prs.tiff ['r=0.366', 'M1=0.332', 'M2=0.461']
# ['r', '0.366']
# ['M1', '0.332']
# ['M2', '0.461']
# {'name': 'Image A: C1-WT-12 LD.tiff & Image B: C3-WT-12 prs.tiff', 'r': '0.366', 'M1': '0.332', 'M2': '0.461'}
# pre process done, total 3 file(s)...
#                                                  name      r     M1     M2
# 0   Image A: M1 Spast WT LD.tiff & Image B: M1 Spa...  0.412  0.213  0.891
# 1   Image A: M1 Spast WT LD-2.tiff & Image B: M1 S...  0.519  0.295  0.985
# 2   Image A: M1 Spast WT LD-3.tiff & Image B: M1 S...  0.425  0.199   0.99
# 3   Image A: M1 Spast WT LD-4.tiff & Image B: M1 S...  0.593  0.482  0.863
# 0   Image A: C1-RH-1 LD.tiff & Image B: C3-RH-1 Pr...  0.321  0.408  0.333
# 1   Image A: C1-RH-2 LD.tiff & Image B: C3-RH-2 Pr...  0.148  0.147  0.159
# 2   Image A: C1-RH-3 LD.tiff & Image B: C3-RH-3 Pr...  0.072  0.093  0.088
# 3   Image A: C1-RH-4 LD.tiff & Image B: C3-RH-4 Pr...   0.43  0.574  0.349
# 4   Image A: C1-RH-5 LD.tiff & Image B: C3-RH-5 Pr...  0.059  0.106  0.069
# 5   Image A: C1-RH-6 LD.tiff & Image B: C3-RH-6 Pr...  0.226  0.219  0.257
# 6   Image A: C1-RH-7 LD.tiff & Image B: C3-RH-7 Pr...  0.118  0.098  0.186
# 7   Image A: C1-RH-8 LD.tiff & Image B: C3-RH-8 Pr...  0.321  0.429  0.271
# 8   Image A: C1-RH-9 LD.tiff & Image B: C3-RH-9 Pr...  0.473  0.534  0.487
# 9   Image A: C1-RH-10 LD.tiff & Image B: C3-RH-10 ...  0.294  0.232  0.459
# 10  Image A: C1-RH-11 LD.tiff & Image B: C3-RH-11 ...  0.386  0.488  0.328
# 11  Image A: C1-RH-12 LD.tiff & Image B: C3-RH-12 ...  0.158  0.176  0.195
# 0   Image A: C1-WT-1 LD.tiff & Image B: C3-WT-1 pr...  0.264  0.227  0.365
# 1   Image A: C1-WT-2 LD.tiff & Image B: C3-WT-2 pr...  0.587  0.462  0.786
# 2   Image A: C1-WT-3 LD.tiff & Image B: C3-WT-3 pr...  0.338  0.213  0.578
# 3   Image A: C1-WT-4 LD.tiff & Image B: C3-WT-4 pr...  0.302   0.27  0.372
# 4   Image A: C1-WT-5 LD.tiff & Image B: C3-WT-5 pr...    0.6  0.677  0.584
# 5   Image A: C1-WT-6 LD.tiff & Image B: C3-WT-6 pr...  0.734  0.653  0.836
# 6   Image A: C1-WT-7 LD.tiff & Image B: C3-WT-7 pr...  0.303    0.2  0.529
# 7   Image A: C1-WT-8 LD.tiff & Image B: C3-WT-8 pr...  0.448  0.305  0.694
# 8   Image A: C1-WT-9 LD.tiff & Image B: C3-WT-9 pr...  0.384  0.318  0.496
# 9   Image A: C1-WT-10 LD.tiff & Image B: C3-WT-10 ...   0.38  0.512   0.33
# 10  Image A: C1-WT-11 LD.tiff & Image B: C3-WT-11 ...  0.498  0.388  0.673
# 11  Image A: C1-WT-12 LD.tiff & Image B: C3-WT-12 ...  0.366  0.332  0.461
